# %% [markdown]
# ### LIBRARY

# %%
import pandas as pd
import requests
import random
import time
import math

# %% [markdown]
# ### SET UP THE ENVIRONMENT

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0",
    "Accept-Language": 'en-US,en;q=0.9',
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Referer": "https://tiki.vn/",
    "From": "",
    "af-ac-enc-dat": "",
    "x-api-source": "pc"
}

# %% [markdown]
# ### EXTRACT GROUP DATA

# %%
URL = "https://api.tiki.vn/raiden/v2/menu-config?platform=desktop"

# %%
response = requests.get(URL, headers=HEADERS)
time.sleep(random.uniform(3.2, 8.7))
if response.status_code == 200:
    data = response.json()
    print(f"Success to fetch {len(data["menu_block"]["items"])} groups.")
else:
    print("Failed to fetch data:", response.status_code)

# %% [markdown]
# ### EXTRACT GROUP ID
# Extract the group id = 1846, 1789

# %%
group = data["menu_block"]["items"]
group_list = []
for group in group:
    link = group["link"]
    group_id = link.split("/")[-1][1:]
    text = group["text"]
    
    # if group_id in ["1789"]:
    if group_id in ["1846", "1789"]:
        group_list.append([group_id, text])

group = pd.DataFrame(group_list, columns=["GroupID", "Name"])
print(f"Success to extract {len(group)} needed groups.")
print(group["GroupID"].values)

# %% [markdown]
# ### EXTRACT CATEGORY HIERARCHY

# %%
category_list = []
for group_id, group_name in zip(group["GroupID"], group["Name"]):
    parent_url = f"https://tiki.vn/api/v2/categories?parent_id={group_id}"
    parent_response = requests.get(parent_url, headers=HEADERS)
    time.sleep(random.uniform(3.2, 8.7))
    if parent_response.status_code == 200:
        parent_data = parent_response.json()
        if not parent_data["data"]:
            category_list.append([group_id, group_name, None, None, None, None, None, None])
        else:
            for parent_category in parent_data["data"]:
                parent_id = parent_category["id"]
                parent_name = parent_category["name"]
                
                child_url = f"https://tiki.vn/api/v2/categories?parent_id={parent_id}"
                child_response = requests.get(child_url, headers=HEADERS)
                time.sleep(random.uniform(3.2, 8.7))
                
                if child_response.status_code == 200:
                    child_data = child_response.json()
                    if not child_data["data"]:
                        category_list.append([group_id, group_name, parent_id, parent_name, None, None, None, None])
                    else:
                        for child_category in child_data["data"]:
                            child_id = child_category["id"]
                            child_name = child_category["name"]
                            
                            type_url = f"https://tiki.vn/api/v2/categories?parent_id={child_id}"
                            type_response = requests.get(type_url, headers=HEADERS)
                            time.sleep(random.uniform(3.2, 8.7))
                            
                            if type_response.status_code == 200:
                                type_data = type_response.json()
                                if type_data["data"]:
                                    for type_item in type_data["data"]:
                                        type_id = type_item.get("id")
                                        type_name = type_item.get("name")
                                        category_list.append([group_id, group_name, parent_id, parent_name, child_id, child_name, type_id, type_name])
                                else:
                                    category_list.append([group_id, group_name, parent_id, parent_name, child_id, child_name, None, None])

category_df = pd.DataFrame(category_list, columns=["GroupID", "GroupName", "MasterCategoryID", "MasterCategoryName", "CategoryID", "CategoryName", "SubCategoryID", "SubCategoryName"])

# %%
print(f"Success to fetch {len(category_df)} categories.")

# %% [markdown]
# ### TRANSFORM CATEGORY HIERARCHY

# %%
def remove_single_category(df):
    # Group the DataFrame by MasterCategoryID and count the unique CategoryID values
    category_counts = df.groupby('MasterCategoryID')['CategoryID'].nunique()
    
    # Create a mask for MasterCategoryIDs with only one CategoryID
    single_category_mask = category_counts == 1
    
    # Drop the CategoryID and CategoryName columns for rows where there is only one CategoryID
    df.loc[df['MasterCategoryID'].isin(single_category_mask[single_category_mask].index), ['CategoryID', 'CategoryName']] = [None, None]
    
    return df

# %%
cleaned_df = remove_single_category(category_df)

# %%
def transform_category(row):
    # Handle MasterCategory and Category
    if pd.isna(row['CategoryID']):
        master_category_id = row['MasterCategoryID']
        master_category_name = row['MasterCategoryName']
        category_id = row['MasterCategoryID']
        category_name = row['MasterCategoryName']
        is_category = 0
    else:
        master_category_id = row['MasterCategoryID']
        master_category_name = row['MasterCategoryName']
        category_id = row['CategoryID']
        category_name = row['CategoryName']
        is_category = 1

    # Handle SubCategory
    if pd.isna(row['SubCategoryID']):
        sub_category_id = category_id
        sub_category_name = category_name
        is_sub_category = 0
    else:
        sub_category_id = row['SubCategoryID']
        sub_category_name = row['SubCategoryName']
        is_sub_category = 1

    return pd.Series([
        master_category_id, master_category_name, category_id, category_name,
        is_category, sub_category_id, sub_category_name, is_sub_category
    ])

# %%
print("Check null for each column in category")
for column in category_df.columns:
    null_percentage = category_df[column].isnull().mean() * 100
    print(f"Null percentage for {column}: {null_percentage:.2f}%")
category_df.head()

# %%
category_df[['MasterCategoryID', 'MasterCategoryName', 'CategoryID', 'CategoryName',
             'isCategory', 'SubCategoryID', 'SubCategoryName', 'isSubCategory']] = category_df.apply(transform_category, axis=1, result_type='expand')

# %%
print("Check null for each column in category")
for column in category_df.columns:
    null_percentage = category_df[column].isnull().mean() * 100
    print(f"Null percentage for {column}: {null_percentage:.2f}%")
category_df.head()

# %%
category_df.columns

# %%
category_df["GroupID"] = category_df["GroupID"].astype(int)
category_df["MasterCategoryID"] = category_df["MasterCategoryID"].astype(int)
category_df["CategoryID"] = category_df["CategoryID"].astype(int)
category_df["SubCategoryID"] = category_df["SubCategoryID"].astype(int)

# %%
group = group.drop_duplicates()

master_category = category_df[["MasterCategoryID", "GroupID", "MasterCategoryName"]].drop_duplicates()
master_category = master_category.rename(columns={"MasterCategoryName": "Name"})

category = category_df[["CategoryID", "MasterCategoryID", "CategoryName", "isCategory"]].drop_duplicates()
category = category.rename(columns={"CategoryName": "Name"})

sub_category = category_df[["SubCategoryID", "CategoryID", "SubCategoryName", "isSubCategory"]].drop_duplicates()
sub_category = sub_category.rename(columns={"SubCategoryName": "Name"})

# %%
print(f"Success to transform {len(master_category)} master categories.")
print(f"Success to transform {len(category)} categories.")
print(f"Success to transform {len(sub_category)} sub categories.")

# %% [markdown]
# ### EXTRACT PRODUCT ID THROUGH SUB-CATEGORY ID

# %%
master_category = pd.read_csv("category_data/master_category.csv")
master_category = pd.DataFrame(master_category)
category = pd.read_csv("category_data/category.csv")
category = pd.DataFrame(category)
sub_category = pd.read_csv("category_data/sub_category.csv")
sub_category = pd.DataFrame(sub_category)

# %%
def retrieve_product_ids(sub_category_id):
    base_url = "https://tiki.vn/api/personalish/v1/blocks/listings"
    PARAMS = {"category": sub_category_id, 
              "page": 1}
    response = requests.get(base_url, headers=HEADERS, params=PARAMS)
    time.sleep(random.uniform(3.2, 8.7))
    
    data = response.json()
    total_page = data["paging"]["last_page"]
    
    # Fetch data from each page
    product_ids = []
    for page in range(1, total_page + 1):
        PARAMS = {"category": sub_category_id, 
                  "page": page}
        response = requests.get(base_url, headers=HEADERS, params=PARAMS)
        time.sleep(random.uniform(3.2, 8.7))
        
        data = response.json()
        for item in data["data"]:
            product_ids.append(item["id"])

    return product_ids

# %%
product_df = []

for sub_category_id in sub_category['SubCategoryID']:
    product_ids = retrieve_product_ids(sub_category_id)
    for product_id in product_ids:
        product_df.append({'SubCategoryID': sub_category_id, 'ProductID': product_id})

# Convert the list of dictionaries to a DataFrame
product_ids_df = pd.DataFrame(product_df)

# %%
# product_ids_df.to_csv("product_ids.csv", index=False, encoding='utf-8-sig')
product_ids_df = pd.read_csv("data/product_ids.csv")
product_ids_df = pd.DataFrame(product_ids_df)

# %%
product_ids_df
# Out:
#        SubCategoryID  ProductID
# 0               1795  184036446
# 1               1795  184059211
# 2               1795   57809866
# 3               1795  120295859
# 4               1795  123345348
# ...              ...        ...
# 23821          28926  249024285
# 23822          28926  204425773
# 23823          28926   13429081
# 23824          28926   72843893
# 23825          28926   90524342
#
# [23826 rows x 2 columns]

# %%
def get_product_data(row):
    product_id = row['ProductID']
    URL = f"https://tiki.vn/api/v2/products/{product_id}"
    PARAMS = {}
    
    max_retries = 5  # Maximum number of retries
    retry_delay = 20  # Delay between retries in seconds

    for attempt in range(max_retries):
        try:
            response = requests.get(URL, headers=HEADERS, params=PARAMS)
            time.sleep(random.uniform(3.2, 6.2))
            print(f"Success to fetch feedback data for {product_id}")
            break
        except requests.exceptions.ConnectionError as e:
            if attempt == max_retries - 1:
                print(f"Failed to fetch feedback data for {product_id} after {max_retries} attempts.")
                return pd.DataFrame()  # Return an empty DataFrame if all attempts fail
            print(f"Failed to fetch feedback data for {product_id}. Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay + random.uniform(0, 5))  # Add a random delay to avoid synchronization issues
    
    data = response.json()

    product_data = {
        'SubCategoryID': row['SubCategoryID'],
        'ProductID': data['id'],
        'product_name': data.get('name', None),
        'product_url': data.get('short_url', None),
        'pricing_current': data.get('price', None),
        'pricing_original': data.get('original_price', None),
        'product_image_url': data.get('thumbnail_url', None),
        'inventory_status': data.get('inventory_status', None),
        'inventory_type': data.get('inventory_type', None),
        'created_date': data.get('day_ago_created', None),
        'quantity_sold': data.get('all_time_quantity_sold', None),
        'brand_id': data.get('brand', {}).get('id', None),
        'brand_name': data.get('brand', {}).get('name', None),
        'brand_slug': data.get('brand', {}).get('slug', None),
        'seller_id': data.get('current_seller', {}).get('id', 0) if data.get('current_seller') else 0,
        'seller_name': data.get('current_seller', {}).get('name', 0) if data.get('current_seller') else 0,
        'seller_link': data.get('current_seller', {}).get('link', 0) if data.get('current_seller') else 0,
        'seller_image_url': data.get('current_seller', {}).get('logo', 0) if data.get('current_seller') else 0
    }

    category_id = data['breadcrumbs'][-2]['category_id']
    product_data['category_id'] = category_id
    
    return product_data

# %%
product = product_ids_df.apply(get_product_data, axis=1, result_type='expand')

# Convert the result to a DataFrame
product_df = pd.DataFrame(product)
# Out:
# Success to fetch feedback data for 184036446
# Success to fetch feedback data for 184059211
# Success to fetch feedback data for 57809866
# Success to fetch feedback data for 120295859
# Success to fetch feedback data for 123345348
# Success to fetch feedback data for 121744434
# Success to fetch feedback data for 189466001
# Success to fetch feedback data for 125590981
# Success to fetch feedback data for 126050455
# Success to fetch feedback data for 172329599
# Success to fetch feedback data for 29931445
# Success to fetch feedback data for 181266509
# Success to fetch feedback data for 140184098
# Success to fetch feedback data for 192859201
# Success to fetch feedback data for 181918564
# Success to fetch feedback data for 197966909
# Success to fetch feedback data for 155833852
# Success to fetch feedback data for 143359355
# Success to fetch feedback data for 151463645
# Success to fetch feedback data for 158895857
# Success to fetch feedback data for 140144656
# Success to fetch feedback data for 147969070
# Success to fetch feedback data for 196760330
# Success to fetch feedback data for 181216830
# Success to fetch feedback data for 140747649
# Success to fetch feedback data for 249955152
# Success to fetch feedback data for 249890023
# Success to fetch feedback data for 192348147
# Success to fetch feedback data for 213931247
# Success to fetch feedback data for 247730209
# Success to fetch feedback data for 244355503
# Success to fetch feedback data for 273411988
# Success to fetch feedback data for 274440344
# Success to fetch feedback data for 273640492
# Success to fetch feedback data for 245770363
# Success to fetch feedback data for 262589811
# Success to fetch feedback data for 273897590
# Success to fetch feedback data for 273388474
# Success to fetch feedback data for 273360836
# Success to fetch feedback data for 261965186
# Success to fetch feedback data for 255866251
# Success to fetch feedback data for 274762212
# Success to fetch feedback data for 253443894
# Success to fetch feedback data for 270636882
# Success to fetch feedback data for 274191773
# Success to fetch feedback data for 273373420
# Success to fetch feedback data for 273664463
# Success to fetch feedback data for 204872160
# Success to fetch feedback data for 252428990
# Success to fetch feedback data for 274639765
# Success to fetch feedback data for 274840632
# Success to fetch feedback data for 274610468
# Success to fetch feedback data for 249168949
# Success to fetch feedback data for 274856742
# Success to fetch feedback data for 274857095
# Success to fetch feedback data for 270510406
# Success to fetch feedback data for 249178196
# Success to fetch feedback data for 273955111
# Success to fetch feedback data for 274544634
# Success to fetch feedback data for 274116886
# Success to fetch feedback data for 204671569
# Success to fetch feedback data for 273016223
# Success to fetch feedback data for 274568845
# Success to fetch feedback data for 273366296
# Success to fetch feedback data for 271730109
# Success to fetch feedback data for 274506430
# Success to fetch feedback data for 274498287
# Success to fetch feedback data for 273942001
# Success to fetch feedback data for 271235147
# Success to fetch feedback data for 273258830
# Success to fetch feedback data for 197214029
# Success to fetch feedback data for 274099409
# Success to fetch feedback data for 271982547
# Success to fetch feedback data for 260406257
# Success to fetch feedback data for 190544267
# Success to fetch feedback data for 191689878
# Success to fetch feedback data for 273359059
# Success to fetch feedback data for 273430216
# Success to fetch feedback data for 207268158
# Success to fetch feedback data for 212040689
# Success to fetch feedback data for 168320000
# Success to fetch feedback data for 230157205
# Success to fetch feedback data for 248704404
# Success to fetch feedback data for 273127929
# Success to fetch feedback data for 270832077
# Success to fetch feedback data for 274639670
# Success to fetch feedback data for 273438724
# Success to fetch feedback data for 273373436
# Success to fetch feedback data for 271494404
# Success to fetch feedback data for 263073555
# Success to fetch feedback data for 193366048
# Success to fetch feedback data for 273636845
# Success to fetch feedback data for 251275686
# Success to fetch feedback data for 261946899
# Success to fetch feedback data for 262514707
# Success to fetch feedback data for 262516014
# Success to fetch feedback data for 274542883
# Success to fetch feedback data for 258667842
# Success to fetch feedback data for 212040697
# Success to fetch feedback data for 274059475
# Success to fetch feedback data for 263274580
# Success to fetch feedback data for 274316885
# Success to fetch feedback data for 190701486
# Success to fetch feedback data for 225228869
# Success to fetch feedback data for 274608056
# Success to fetch feedback data for 274617822
# Success to fetch feedback data for 272909668
# Success to fetch feedback data for 249156531
# Success to fetch feedback data for 274392442
# Success to fetch feedback data for 273774937
# Success to fetch feedback data for 272270730
# Success to fetch feedback data for 271128271
# Success to fetch feedback data for 274507025
# Success to fetch feedback data for 251930431
# Success to fetch feedback data for 272348047
# Success to fetch feedback data for 244303202
# Success to fetch feedback data for 270736028
# Success to fetch feedback data for 274498288
# Success to fetch feedback data for 198858451
# Success to fetch feedback data for 274179544
# Success to fetch feedback data for 273252926
# Success to fetch feedback data for 271134741
# Success to fetch feedback data for 274166857
# Success to fetch feedback data for 273610368
# Success to fetch feedback data for 270160350
# Success to fetch feedback data for 271966786
# Success to fetch feedback data for 273718967
# Success to fetch feedback data for 273958512
# Success to fetch feedback data for 273389282
# Success to fetch feedback data for 176438864
# Success to fetch feedback data for 274065746
# Success to fetch feedback data for 219400421
# Success to fetch feedback data for 244332381
# Success to fetch feedback data for 251930414
# Success to fetch feedback data for 225960096
# Success to fetch feedback data for 250109584
# Success to fetch feedback data for 273185467
# Success to fetch feedback data for 273438769
# Success to fetch feedback data for 274545326
# Success to fetch feedback data for 274762125
# Success to fetch feedback data for 273378164
# Success to fetch feedback data for 263309601
# Success to fetch feedback data for 242771940
# Success to fetch feedback data for 248754839
# Success to fetch feedback data for 273595363
# Success to fetch feedback data for 272234493
# Success to fetch feedback data for 230155305
# Success to fetch feedback data for 198671718
# Success to fetch feedback data for 270164674
# Success to fetch feedback data for 249168300
# Success to fetch feedback data for 274610514
# Success to fetch feedback data for 274619667
# Success to fetch feedback data for 273553649
# Success to fetch feedback data for 274611998
# Success to fetch feedback data for 273410030
# Success to fetch feedback data for 274542808
# Success to fetch feedback data for 273186911
# Success to fetch feedback data for 198968094
# Success to fetch feedback data for 216934468
# Success to fetch feedback data for 205846229
# Success to fetch feedback data for 273897523
# Success to fetch feedback data for 274681248
# Success to fetch feedback data for 197214015
# Success to fetch feedback data for 249890677
# Success to fetch feedback data for 272273169
# Success to fetch feedback data for 274375122
# Success to fetch feedback data for 243165179
# Success to fetch feedback data for 271973414
# Success to fetch feedback data for 272273680
# Success to fetch feedback data for 274564360
# Success to fetch feedback data for 274037365
# Success to fetch feedback data for 270975124
# Success to fetch feedback data for 271046571
# Success to fetch feedback data for 230055130
# Success to fetch feedback data for 212329857
# Success to fetch feedback data for 244182370
# Success to fetch feedback data for 207883258
# Success to fetch feedback data for 251407092
# Success to fetch feedback data for 272834546
# Success to fetch feedback data for 262660017
# Success to fetch feedback data for 272200109
# Success to fetch feedback data for 274030201
# Success to fetch feedback data for 196348143
# Success to fetch feedback data for 273438458
# Success to fetch feedback data for 251514670
# Success to fetch feedback data for 253443652
# Success to fetch feedback data for 168317790
# Success to fetch feedback data for 216092766
# Success to fetch feedback data for 194462682
# Success to fetch feedback data for 242657652
# Success to fetch feedback data for 202035122
# Success to fetch feedback data for 263059025
# Success to fetch feedback data for 274724268
# Success to fetch feedback data for 273186334
# Success to fetch feedback data for 203278278
# Success to fetch feedback data for 274638430
# Success to fetch feedback data for 248762051
# Success to fetch feedback data for 273511450
# Success to fetch feedback data for 273454566
# Success to fetch feedback data for 274316036
# Success to fetch feedback data for 208171115
# Success to fetch feedback data for 274393574
# Success to fetch feedback data for 272113804
# Success to fetch feedback data for 274608680
# Success to fetch feedback data for 249169833
# Success to fetch feedback data for 273165324
# Success to fetch feedback data for 274162900
# Success to fetch feedback data for 250113073
# Success to fetch feedback data for 273440662
# Success to fetch feedback data for 208193365
# Success to fetch feedback data for 270814388
# Success to fetch feedback data for 215543460
# Success to fetch feedback data for 258373871
# Success to fetch feedback data for 273367316
# Success to fetch feedback data for 273951550
# Success to fetch feedback data for 273683300
# Success to fetch feedback data for 271967379
# Success to fetch feedback data for 274036896
# Success to fetch feedback data for 274456687
# Success to fetch feedback data for 274365104
# Success to fetch feedback data for 272241346
# Success to fetch feedback data for 203853390
# Success to fetch feedback data for 253443788
# Success to fetch feedback data for 217559440
# Success to fetch feedback data for 219392186
# Success to fetch feedback data for 201631518
# Success to fetch feedback data for 213587929
# Success to fetch feedback data for 273359931
# Success to fetch feedback data for 263041214
# Success to fetch feedback data for 248655651
# Success to fetch feedback data for 204802771
# Success to fetch feedback data for 263675862
# Success to fetch feedback data for 270814412
# Success to fetch feedback data for 191764688
# Success to fetch feedback data for 270544863
# Success to fetch feedback data for 263060294
# Success to fetch feedback data for 168779225
# Success to fetch feedback data for 252427658
# Success to fetch feedback data for 273029857
# Success to fetch feedback data for 273610105
# Success to fetch feedback data for 251448280
# Success to fetch feedback data for 188900310
# Success to fetch feedback data for 272056193
# Success to fetch feedback data for 267178005
# Success to fetch feedback data for 242712931
# Success to fetch feedback data for 196197701
# Success to fetch feedback data for 274542983
# Success to fetch feedback data for 272328188
# Success to fetch feedback data for 249153684
# Success to fetch feedback data for 263438008
# Success to fetch feedback data for 274380639
# Success to fetch feedback data for 219397711
# Success to fetch feedback data for 215746882
# Success to fetch feedback data for 197670818
# Success to fetch feedback data for 247829297
# Success to fetch feedback data for 273498357
# Success to fetch feedback data for 273411606
# Success to fetch feedback data for 273958619
# Success to fetch feedback data for 272392928
# Success to fetch feedback data for 273947792
# Success to fetch feedback data for 250111470
# Success to fetch feedback data for 270447782
# Success to fetch feedback data for 274405521
# Success to fetch feedback data for 205750556
# Success to fetch feedback data for 271972435
# Success to fetch feedback data for 272238679
# Success to fetch feedback data for 274095168
# Success to fetch feedback data for 273411607
# Success to fetch feedback data for 115830124
# Success to fetch feedback data for 273650151
# Success to fetch feedback data for 191689727
# Success to fetch feedback data for 270714226
# Success to fetch feedback data for 204066551
# Success to fetch feedback data for 271451188
# Success to fetch feedback data for 271954384
# Success to fetch feedback data for 272850971
# Success to fetch feedback data for 176438844
# Success to fetch feedback data for 249143473
# Success to fetch feedback data for 242712374
# Success to fetch feedback data for 264285233
# Success to fetch feedback data for 248005118
# Success to fetch feedback data for 245770806
# Success to fetch feedback data for 165747145
# Success to fetch feedback data for 247925719
# Success to fetch feedback data for 261962220
# Success to fetch feedback data for 198648645
# Success to fetch feedback data for 181699053
# Success to fetch feedback data for 230203067
# Success to fetch feedback data for 274415640
# Success to fetch feedback data for 254125720
# Success to fetch feedback data for 189658085
# Success to fetch feedback data for 274638822
# Success to fetch feedback data for 270625677
# Success to fetch feedback data for 274160702
# Success to fetch feedback data for 214603586
# Success to fetch feedback data for 274069052
# Success to fetch feedback data for 274625697
# Success to fetch feedback data for 215617756
# Success to fetch feedback data for 273412211
# Success to fetch feedback data for 270260682
# Success to fetch feedback data for 192036708
# Success to fetch feedback data for 274541336
# Success to fetch feedback data for 126682340
# Success to fetch feedback data for 272394241
# Success to fetch feedback data for 248929458
# Success to fetch feedback data for 273258825
# Success to fetch feedback data for 274638659
# Success to fetch feedback data for 274172292
# Success to fetch feedback data for 270814316
# Success to fetch feedback data for 273398391
# Success to fetch feedback data for 273357326
# Success to fetch feedback data for 274693012
# Success to fetch feedback data for 273990229
# Success to fetch feedback data for 249956458
# Success to fetch feedback data for 183330021
# Success to fetch feedback data for 184248127
# Success to fetch feedback data for 184253251
# Success to fetch feedback data for 150724369
# Success to fetch feedback data for 173557858
# Success to fetch feedback data for 195317118
# Success to fetch feedback data for 194498804
# Success to fetch feedback data for 176909016
# Success to fetch feedback data for 162866839
# Success to fetch feedback data for 72310352
# Success to fetch feedback data for 72310420
# Success to fetch feedback data for 160450655
# Success to fetch feedback data for 148696890
# Success to fetch feedback data for 271822675
# Success to fetch feedback data for 262908601
# Success to fetch feedback data for 160434731
# Success to fetch feedback data for 274840089
# Success to fetch feedback data for 274626215
# Success to fetch feedback data for 274840015
# Success to fetch feedback data for 121059239
# Success to fetch feedback data for 274868116
# Success to fetch feedback data for 274101262
# Success to fetch feedback data for 164697930
# Success to fetch feedback data for 188948039
# Success to fetch feedback data for 258787119
# Success to fetch feedback data for 274361820
# Success to fetch feedback data for 263438199
# Success to fetch feedback data for 217158870
# Success to fetch feedback data for 186149961
# Success to fetch feedback data for 273232944
# Success to fetch feedback data for 274626262
# Success to fetch feedback data for 274840058
# Success to fetch feedback data for 274868043
# Success to fetch feedback data for 136364272
# Success to fetch feedback data for 273231495
# Success to fetch feedback data for 249782771
# Success to fetch feedback data for 274560616
# Success to fetch feedback data for 271801317
# Success to fetch feedback data for 274364026
# Success to fetch feedback data for 103168071
# Success to fetch feedback data for 206218031
# Success to fetch feedback data for 175851126
# Success to fetch feedback data for 273407277
# Success to fetch feedback data for 273659145
# Success to fetch feedback data for 274164078
# Success to fetch feedback data for 271364652
# Success to fetch feedback data for 274866839
# Success to fetch feedback data for 205815576
# Success to fetch feedback data for 131028406
# Success to fetch feedback data for 181699208
# Success to fetch feedback data for 273559020
# Success to fetch feedback data for 273366493
# Success to fetch feedback data for 274625942
# Success to fetch feedback data for 274840120
# Success to fetch feedback data for 274625981
# Success to fetch feedback data for 103168844
# Success to fetch feedback data for 272362704
# Success to fetch feedback data for 273348837
# Success to fetch feedback data for 271799133
# Success to fetch feedback data for 225936344
# Success to fetch feedback data for 158742790
# Success to fetch feedback data for 213858174
# Success to fetch feedback data for 160556149
# Success to fetch feedback data for 273653444
# Success to fetch feedback data for 273872197
# Success to fetch feedback data for 105830021
# Success to fetch feedback data for 273684137
# Success to fetch feedback data for 274839974
# Success to fetch feedback data for 274839897
# Success to fetch feedback data for 274186881
# Success to fetch feedback data for 274101255
# Success to fetch feedback data for 274904904
# Success to fetch feedback data for 188030974
# Success to fetch feedback data for 271284934
# Success to fetch feedback data for 195177036
# Success to fetch feedback data for 205897182
# Success to fetch feedback data for 271822725
# Success to fetch feedback data for 217158529
# Success to fetch feedback data for 274663238
# Success to fetch feedback data for 274840100
# Success to fetch feedback data for 274626173
# Success to fetch feedback data for 274164375
# Success to fetch feedback data for 217561341
# Success to fetch feedback data for 125182567
# Success to fetch feedback data for 217706932
# Success to fetch feedback data for 201067649
# Success to fetch feedback data for 139632023
# Success to fetch feedback data for 173387789
# Success to fetch feedback data for 270794184
# Success to fetch feedback data for 43924153
# Success to fetch feedback data for 140940220
# Success to fetch feedback data for 74776150
# Success to fetch feedback data for 128895957
# Success to fetch feedback data for 118486668
# Success to fetch feedback data for 72290345
# Success to fetch feedback data for 185755283
# Success to fetch feedback data for 91281318
# Success to fetch feedback data for 148701811
# Success to fetch feedback data for 169651533
# Success to fetch feedback data for 182850918
# Success to fetch feedback data for 177212711
# Success to fetch feedback data for 271218081
# Success to fetch feedback data for 270707514
# Success to fetch feedback data for 242434782
# Success to fetch feedback data for 274536294
# Success to fetch feedback data for 209927605
# Success to fetch feedback data for 25949745
# Success to fetch feedback data for 153581522
# Success to fetch feedback data for 272222033
# Success to fetch feedback data for 252586291
# Success to fetch feedback data for 217640502
# Success to fetch feedback data for 274638556
# Success to fetch feedback data for 271362153
# Success to fetch feedback data for 273227290
# Success to fetch feedback data for 179547641
# Success to fetch feedback data for 247427990
# Success to fetch feedback data for 169651528
# Success to fetch feedback data for 248766283
# Success to fetch feedback data for 209872337
# Success to fetch feedback data for 258513251
# Success to fetch feedback data for 214756058
# Success to fetch feedback data for 273175604
# Success to fetch feedback data for 263798932
# Success to fetch feedback data for 271530789
# Success to fetch feedback data for 217645692
# Success to fetch feedback data for 217505504
# Success to fetch feedback data for 217505430
# Success to fetch feedback data for 221518066
# Success to fetch feedback data for 271329051
# Success to fetch feedback data for 217548686
# Success to fetch feedback data for 262706645
# Success to fetch feedback data for 197654695
# Success to fetch feedback data for 197652030
# Success to fetch feedback data for 197960169
# Success to fetch feedback data for 168526284
# Success to fetch feedback data for 184578632
# Success to fetch feedback data for 181452535
# Success to fetch feedback data for 167465972
# Success to fetch feedback data for 167466044
# Success to fetch feedback data for 167465704
# Success to fetch feedback data for 170448099
# Success to fetch feedback data for 197666071
# Success to fetch feedback data for 125753416
# Success to fetch feedback data for 125753291
# Success to fetch feedback data for 197651936
# Success to fetch feedback data for 197907038
# Success to fetch feedback data for 84757299
# Success to fetch feedback data for 171852890
# Success to fetch feedback data for 196176544
# Success to fetch feedback data for 174085242
# Success to fetch feedback data for 197905982
# Success to fetch feedback data for 249730344
# Success to fetch feedback data for 224873580
# Success to fetch feedback data for 215097578
# Success to fetch feedback data for 197902452
# Success to fetch feedback data for 252073075
# Success to fetch feedback data for 251772653
# Success to fetch feedback data for 271290719
# Success to fetch feedback data for 252865847
# Success to fetch feedback data for 274019932
# Success to fetch feedback data for 271234577
# Success to fetch feedback data for 248185228
# Success to fetch feedback data for 274516951
# Success to fetch feedback data for 248235765
# Success to fetch feedback data for 252073056
# Success to fetch feedback data for 252072952
# Success to fetch feedback data for 212261734
# Success to fetch feedback data for 270471106
# Success to fetch feedback data for 215119245
# Success to fetch feedback data for 274524033
# Success to fetch feedback data for 258766897
# Success to fetch feedback data for 249851724
# Success to fetch feedback data for 200829966
# Success to fetch feedback data for 200848570
# Success to fetch feedback data for 274257669
# Success to fetch feedback data for 200819471
# Success to fetch feedback data for 253380146
# Success to fetch feedback data for 191089547
# Success to fetch feedback data for 224186586
# Success to fetch feedback data for 215125094
# Success to fetch feedback data for 271234313
# Success to fetch feedback data for 201001781
# Success to fetch feedback data for 191636459
# Success to fetch feedback data for 200816374
# Success to fetch feedback data for 274019962
# Success to fetch feedback data for 215135773
# Success to fetch feedback data for 270976558
# Success to fetch feedback data for 217276360
# Success to fetch feedback data for 160051501
# Success to fetch feedback data for 249730338
# Success to fetch feedback data for 167465856
# Success to fetch feedback data for 274516245
# Success to fetch feedback data for 252073258
# Success to fetch feedback data for 271389593
# Success to fetch feedback data for 270471101
# Success to fetch feedback data for 171685825
# Success to fetch feedback data for 249730334
# Success to fetch feedback data for 195894801
# Success to fetch feedback data for 252073151
# Success to fetch feedback data for 271368354
# Success to fetch feedback data for 274524050
# Success to fetch feedback data for 263117493
# Success to fetch feedback data for 225912504
# Success to fetch feedback data for 170449059
# Success to fetch feedback data for 172920927
# Success to fetch feedback data for 274424330
# Success to fetch feedback data for 163914808
# Success to fetch feedback data for 204237269
# Success to fetch feedback data for 181977398
# Success to fetch feedback data for 31261844
# Success to fetch feedback data for 73842403
# Success to fetch feedback data for 11415485
# Success to fetch feedback data for 170165701
# Success to fetch feedback data for 42333095
# Success to fetch feedback data for 144200408
# Success to fetch feedback data for 117929342
# Success to fetch feedback data for 11251711
# Success to fetch feedback data for 16521748
# Success to fetch feedback data for 4048581
# Success to fetch feedback data for 23142193
# Success to fetch feedback data for 192694043
# Success to fetch feedback data for 117929538
# Success to fetch feedback data for 47292697
# Success to fetch feedback data for 31820638
# Success to fetch feedback data for 55197731
# Success to fetch feedback data for 4048043
# Success to fetch feedback data for 29440849
# Success to fetch feedback data for 4059671
# Success to fetch feedback data for 170727305
# Success to fetch feedback data for 14508445
# Success to fetch feedback data for 157835051
# Success to fetch feedback data for 257866809
# Success to fetch feedback data for 121154009
# Success to fetch feedback data for 11376644
# Success to fetch feedback data for 113475741
# Success to fetch feedback data for 94453667
# Success to fetch feedback data for 52326343
# Success to fetch feedback data for 54882670
# Success to fetch feedback data for 156222386
# Success to fetch feedback data for 54989813
# Success to fetch feedback data for 16518032
# Success to fetch feedback data for 52481412
# Success to fetch feedback data for 117347869
# Success to fetch feedback data for 54683561
# Success to fetch feedback data for 125171841
# Success to fetch feedback data for 15428119
# Success to fetch feedback data for 170165658
# Success to fetch feedback data for 23865953
# Success to fetch feedback data for 172537996
# Success to fetch feedback data for 136199385
# Success to fetch feedback data for 258330471
# Success to fetch feedback data for 252884859
# Success to fetch feedback data for 53380152
# Success to fetch feedback data for 220678495
# Success to fetch feedback data for 198868735
# Success to fetch feedback data for 220670303
# Success to fetch feedback data for 257861524
# Success to fetch feedback data for 52002453
# Failed to fetch feedback data for 173789184. Retrying in 20 seconds...
# Success to fetch feedback data for 173789184
# Success to fetch feedback data for 258668285
# Success to fetch feedback data for 102620086
# Success to fetch feedback data for 226552005
# Success to fetch feedback data for 16518729
# Success to fetch feedback data for 274869053
# Success to fetch feedback data for 198868573
# Success to fetch feedback data for 58146831
# Success to fetch feedback data for 29446449
# Success to fetch feedback data for 252884932
# Success to fetch feedback data for 108924121
# Success to fetch feedback data for 191659040
# Success to fetch feedback data for 183743642
# Success to fetch feedback data for 190725476
# Success to fetch feedback data for 146563301
# Success to fetch feedback data for 187188428
# Success to fetch feedback data for 186984673
# Success to fetch feedback data for 179403775
# Success to fetch feedback data for 127377025
# Success to fetch feedback data for 143022294
# Success to fetch feedback data for 155530449
# Success to fetch feedback data for 180396084
# Success to fetch feedback data for 179167744
# Success to fetch feedback data for 151839086
# Success to fetch feedback data for 180396187
# Success to fetch feedback data for 163871476
# Success to fetch feedback data for 180396111
# Success to fetch feedback data for 135268243
# Success to fetch feedback data for 155831428
# Success to fetch feedback data for 70692002
# Success to fetch feedback data for 77117709
# Success to fetch feedback data for 160305537
# Success to fetch feedback data for 177639585
# Success to fetch feedback data for 177455788
# Success to fetch feedback data for 189466548
# Success to fetch feedback data for 177631977
# Success to fetch feedback data for 177614108
# Success to fetch feedback data for 180396082
# Success to fetch feedback data for 161225920
# Success to fetch feedback data for 67982880
# Success to fetch feedback data for 134947044
# Success to fetch feedback data for 179408253
# Success to fetch feedback data for 174216794
# Success to fetch feedback data for 190725467
# Success to fetch feedback data for 106318753
# Success to fetch feedback data for 192926769
# Success to fetch feedback data for 197751617
# Success to fetch feedback data for 183243309
# Success to fetch feedback data for 140743794
# Success to fetch feedback data for 173151886
# Success to fetch feedback data for 196907103
# Success to fetch feedback data for 191694005
# Success to fetch feedback data for 189572223
# Success to fetch feedback data for 136940990
# Success to fetch feedback data for 160445791
# Success to fetch feedback data for 169264166
# Success to fetch feedback data for 121405779
# Success to fetch feedback data for 189365717
# Success to fetch feedback data for 196161158
# Success to fetch feedback data for 164397018
# Success to fetch feedback data for 155530453
# Success to fetch feedback data for 186434417
# Success to fetch feedback data for 189572199
# Success to fetch feedback data for 189696941
# Success to fetch feedback data for 180396140
# Success to fetch feedback data for 163871484
# Success to fetch feedback data for 186985454
# Success to fetch feedback data for 136951412
# Success to fetch feedback data for 196911702
# Success to fetch feedback data for 143172648
# Success to fetch feedback data for 196906988
# Success to fetch feedback data for 162188204
# Success to fetch feedback data for 136975279
# Success to fetch feedback data for 136979185
# Success to fetch feedback data for 186479817
# Success to fetch feedback data for 186479612
# Success to fetch feedback data for 196909214
# Success to fetch feedback data for 189698164
# Success to fetch feedback data for 158583026
# Success to fetch feedback data for 172472210
# Success to fetch feedback data for 189466659
# Success to fetch feedback data for 155974507
# Success to fetch feedback data for 186191702
# Success to fetch feedback data for 134496483
# Success to fetch feedback data for 197770991
# Success to fetch feedback data for 151676582
# Success to fetch feedback data for 193859847
# Success to fetch feedback data for 189697988
# Success to fetch feedback data for 160449446
# Success to fetch feedback data for 158583221
# Success to fetch feedback data for 189696865
# Success to fetch feedback data for 190725443
# Success to fetch feedback data for 136983195
# Success to fetch feedback data for 189696649
# Success to fetch feedback data for 187196562
# Success to fetch feedback data for 189700810
# Success to fetch feedback data for 186434665
# Success to fetch feedback data for 164960057
# Success to fetch feedback data for 191726143
# Success to fetch feedback data for 186635020
# Success to fetch feedback data for 189696547
# Success to fetch feedback data for 191717423
# Success to fetch feedback data for 160449183
# Success to fetch feedback data for 92555400
# Success to fetch feedback data for 160449181
# Success to fetch feedback data for 141322626
# Success to fetch feedback data for 189700471
# Success to fetch feedback data for 179409290
# Success to fetch feedback data for 137127320
# Success to fetch feedback data for 155530401
# Success to fetch feedback data for 189700765
# Success to fetch feedback data for 186633058
# Success to fetch feedback data for 191723144
# Success to fetch feedback data for 179377370
# Success to fetch feedback data for 117806374
# Success to fetch feedback data for 263753733
# Success to fetch feedback data for 213818760
# Success to fetch feedback data for 201509133
# Success to fetch feedback data for 225205695
# Success to fetch feedback data for 273531041
# Success to fetch feedback data for 273279238
# Success to fetch feedback data for 273486388
# Success to fetch feedback data for 201967460
# Success to fetch feedback data for 249160185
# Success to fetch feedback data for 273643995
# Success to fetch feedback data for 193125722
# Success to fetch feedback data for 273513557
# Success to fetch feedback data for 273602684
# Success to fetch feedback data for 199264057
# Success to fetch feedback data for 199104660
# Success to fetch feedback data for 251546151
# Success to fetch feedback data for 214863346
# Success to fetch feedback data for 273464609
# Success to fetch feedback data for 253300191
# Success to fetch feedback data for 273379339
# Success to fetch feedback data for 273463773
# Success to fetch feedback data for 274368044
# Success to fetch feedback data for 272354928
# Success to fetch feedback data for 206136948
# Success to fetch feedback data for 199053702
# Success to fetch feedback data for 198984680
# Success to fetch feedback data for 225917288
# Success to fetch feedback data for 214615804
# Success to fetch feedback data for 199631690
# Success to fetch feedback data for 273587244
# Success to fetch feedback data for 273456189
# Success to fetch feedback data for 214863371
# Success to fetch feedback data for 195891630
# Success to fetch feedback data for 273519255
# Success to fetch feedback data for 248277859
# Success to fetch feedback data for 205305631
# Success to fetch feedback data for 198593149
# Success to fetch feedback data for 273217826
# Success to fetch feedback data for 251547656
# Success to fetch feedback data for 251545181
# Success to fetch feedback data for 224114093
# Success to fetch feedback data for 273532075
# Success to fetch feedback data for 225206695
# Success to fetch feedback data for 252356843
# Success to fetch feedback data for 206862580
# Success to fetch feedback data for 190507969
# Success to fetch feedback data for 180396090
# Success to fetch feedback data for 214615798
# Success to fetch feedback data for 192729516
# Success to fetch feedback data for 273645818
# Success to fetch feedback data for 273231355
# Success to fetch feedback data for 215097522
# Success to fetch feedback data for 198592225
# Success to fetch feedback data for 252174150
# Success to fetch feedback data for 198592513
# Success to fetch feedback data for 210941889
# Success to fetch feedback data for 273520127
# Success to fetch feedback data for 225363237
# Success to fetch feedback data for 251546384
# Success to fetch feedback data for 249085376
# Success to fetch feedback data for 225226354
# Success to fetch feedback data for 204677811
# Success to fetch feedback data for 214615797
# Success to fetch feedback data for 248266752
# Success to fetch feedback data for 214593527
# Success to fetch feedback data for 205996228
# Success to fetch feedback data for 251547580
# Success to fetch feedback data for 135092859
# Success to fetch feedback data for 214615807
# Success to fetch feedback data for 270237378
# Success to fetch feedback data for 225934432
# Success to fetch feedback data for 273664679
# Success to fetch feedback data for 273214573
# Success to fetch feedback data for 247829105
# Success to fetch feedback data for 263450606
# Success to fetch feedback data for 225917268
# Success to fetch feedback data for 273537223
# Success to fetch feedback data for 274503930
# Success to fetch feedback data for 262692522
# Success to fetch feedback data for 210941880
# Success to fetch feedback data for 249033674
# Success to fetch feedback data for 207041896
# Success to fetch feedback data for 214619356
# Success to fetch feedback data for 244299479
# Success to fetch feedback data for 249136428
# Success to fetch feedback data for 272526551
# Success to fetch feedback data for 251545298
# Success to fetch feedback data for 273495791
# Success to fetch feedback data for 247443969
# Success to fetch feedback data for 190725464
# Success to fetch feedback data for 213998715
# Success to fetch feedback data for 252566338
# Success to fetch feedback data for 273495615
# Success to fetch feedback data for 248808510
# Success to fetch feedback data for 252011523
# Success to fetch feedback data for 222680363
# Success to fetch feedback data for 206840788
# Success to fetch feedback data for 225917309
# Success to fetch feedback data for 248810963
# Success to fetch feedback data for 252354629
# Success to fetch feedback data for 205999091
# Success to fetch feedback data for 210941887
# Success to fetch feedback data for 206051973
# Success to fetch feedback data for 199901611
# Success to fetch feedback data for 186584312
# Success to fetch feedback data for 273519208
# Success to fetch feedback data for 249960577
# Success to fetch feedback data for 273218013
# Success to fetch feedback data for 248280222
# Success to fetch feedback data for 251547184
# Success to fetch feedback data for 199691055
# Success to fetch feedback data for 225206828
# Success to fetch feedback data for 258569050
# Success to fetch feedback data for 249035977
# Success to fetch feedback data for 274033248
# Success to fetch feedback data for 273292838
# Success to fetch feedback data for 273645750
# Success to fetch feedback data for 248280562
# Success to fetch feedback data for 210941886
# Success to fetch feedback data for 273231142
# Success to fetch feedback data for 195902379
# Success to fetch feedback data for 205962360
# Success to fetch feedback data for 198592308
# Success to fetch feedback data for 225917324
# Success to fetch feedback data for 225917269
# Success to fetch feedback data for 253414659
# Success to fetch feedback data for 135093811
# Success to fetch feedback data for 252064720
# Success to fetch feedback data for 155830485
# Success to fetch feedback data for 214615800
# Success to fetch feedback data for 274502092
# Success to fetch feedback data for 203317484
# Success to fetch feedback data for 252212309
# Success to fetch feedback data for 208603647
# Success to fetch feedback data for 273520871
# Success to fetch feedback data for 270139751
# Success to fetch feedback data for 210941904
# Success to fetch feedback data for 274825404
# Success to fetch feedback data for 273523285
# Success to fetch feedback data for 199618391
# Success to fetch feedback data for 210941891
# Success to fetch feedback data for 198995750
# Success to fetch feedback data for 248287190
# Success to fetch feedback data for 273498232
# Success to fetch feedback data for 253403038
# Success to fetch feedback data for 269955670
# Success to fetch feedback data for 274754596
# Success to fetch feedback data for 273524532
# Success to fetch feedback data for 252220920
# Success to fetch feedback data for 210941894
# Success to fetch feedback data for 252509121
# Success to fetch feedback data for 273458720
# Success to fetch feedback data for 247459364
# Success to fetch feedback data for 190725441
# Success to fetch feedback data for 272373606
# Success to fetch feedback data for 210941902
# Success to fetch feedback data for 210941895
# Success to fetch feedback data for 252566514
# Success to fetch feedback data for 213755302
# Success to fetch feedback data for 270238220
# Success to fetch feedback data for 270207303
# Success to fetch feedback data for 253096916
# Success to fetch feedback data for 214944753
# Success to fetch feedback data for 214956101
# Success to fetch feedback data for 214863348
# Success to fetch feedback data for 271382436
# Success to fetch feedback data for 271389249
# Success to fetch feedback data for 273747303
# Success to fetch feedback data for 213867594
# Success to fetch feedback data for 198436830
# Success to fetch feedback data for 270207528
# Success to fetch feedback data for 274724321
# Success to fetch feedback data for 270958179
# Success to fetch feedback data for 273588815
# Success to fetch feedback data for 272449342
# Success to fetch feedback data for 203790066
# Success to fetch feedback data for 273186974
# Success to fetch feedback data for 195902569
# Success to fetch feedback data for 198462692
# Success to fetch feedback data for 273465024
# Success to fetch feedback data for 273503426
# Success to fetch feedback data for 199520055
# Success to fetch feedback data for 252174116
# Success to fetch feedback data for 252216947
# Success to fetch feedback data for 225917253
# Success to fetch feedback data for 225206280
# Success to fetch feedback data for 222623722
# Success to fetch feedback data for 225917347
# Success to fetch feedback data for 269955838
# Success to fetch feedback data for 253059174
# Success to fetch feedback data for 274854577
# Success to fetch feedback data for 198572369
# Success to fetch feedback data for 198592553
# Success to fetch feedback data for 251545496
# Success to fetch feedback data for 249383414
# Success to fetch feedback data for 225195616
# Success to fetch feedback data for 273590783
# Success to fetch feedback data for 272494029
# Success to fetch feedback data for 271385968
# Success to fetch feedback data for 189588675
# Success to fetch feedback data for 213998268
# Success to fetch feedback data for 201509157
# Success to fetch feedback data for 150656150
# Success to fetch feedback data for 203757948
# Success to fetch feedback data for 274754883
# Success to fetch feedback data for 248913500
# Success to fetch feedback data for 92621126
# Success to fetch feedback data for 214863408
# Success to fetch feedback data for 133697603
# Success to fetch feedback data for 270207358
# Success to fetch feedback data for 249145230
# Success to fetch feedback data for 274420903
# Success to fetch feedback data for 273231106
# Success to fetch feedback data for 181779366
# Success to fetch feedback data for 253300205
# Success to fetch feedback data for 270206343
# Success to fetch feedback data for 193110691
# Success to fetch feedback data for 225917273
# Success to fetch feedback data for 249945720
# Success to fetch feedback data for 183719135
# Success to fetch feedback data for 274608371
# Success to fetch feedback data for 273455715
# Success to fetch feedback data for 203320162
# Success to fetch feedback data for 273634022
# Success to fetch feedback data for 215097526
# Success to fetch feedback data for 198437064
# Success to fetch feedback data for 196673537
# Success to fetch feedback data for 214863409
# Success to fetch feedback data for 189466838
# Success to fetch feedback data for 273466115
# Success to fetch feedback data for 201831052
# Success to fetch feedback data for 155530390
# Success to fetch feedback data for 247443890
# Success to fetch feedback data for 273679080
# Success to fetch feedback data for 225917302
# Success to fetch feedback data for 127363787
# Success to fetch feedback data for 214863351
# Success to fetch feedback data for 198302927
# Success to fetch feedback data for 249669475
# Success to fetch feedback data for 262387524
# Success to fetch feedback data for 214961090
# Success to fetch feedback data for 247716891
# Success to fetch feedback data for 271383201
# Success to fetch feedback data for 222529881
# Success to fetch feedback data for 274831313
# Success to fetch feedback data for 274693075
# Success to fetch feedback data for 273513559
# Success to fetch feedback data for 213568499
# Success to fetch feedback data for 271246114
# Success to fetch feedback data for 271365172
# Success to fetch feedback data for 253300189
# Success to fetch feedback data for 253630333
# Success to fetch feedback data for 225195503
# Success to fetch feedback data for 258839143
# Success to fetch feedback data for 273906240
# Success to fetch feedback data for 270209245
# Success to fetch feedback data for 219385976
# Success to fetch feedback data for 225917335
# Success to fetch feedback data for 213774142
# Success to fetch feedback data for 225942250
# Success to fetch feedback data for 273647623
# Success to fetch feedback data for 249947165
# Success to fetch feedback data for 273502975
# Success to fetch feedback data for 225917244
# Success to fetch feedback data for 190463775
# Success to fetch feedback data for 225211212
# Success to fetch feedback data for 219395853
# Success to fetch feedback data for 225917247
# Success to fetch feedback data for 274032299
# Success to fetch feedback data for 273523458
# Success to fetch feedback data for 273494497
# Success to fetch feedback data for 225205574
# Success to fetch feedback data for 214619946
# Success to fetch feedback data for 222618764
# Success to fetch feedback data for 215097545
# Success to fetch feedback data for 273534234
# Success to fetch feedback data for 248913699
# Success to fetch feedback data for 252173934
# Success to fetch feedback data for 216469746
# Success to fetch feedback data for 193859871
# Success to fetch feedback data for 273534939
# Success to fetch feedback data for 195891105
# Success to fetch feedback data for 140143812
# Success to fetch feedback data for 213998305
# Success to fetch feedback data for 252172447
# Success to fetch feedback data for 248912576
# Success to fetch feedback data for 214863354
# Success to fetch feedback data for 270139607
# Success to fetch feedback data for 214863355
# Success to fetch feedback data for 217777182
# Success to fetch feedback data for 273455506
# Success to fetch feedback data for 274556325
# Success to fetch feedback data for 272828266
# Success to fetch feedback data for 198593129
# Success to fetch feedback data for 274867114
# Success to fetch feedback data for 263451423
# Success to fetch feedback data for 225917341
# Success to fetch feedback data for 249936050
# Success to fetch feedback data for 198123513
# Success to fetch feedback data for 263052607
# Success to fetch feedback data for 263053642
# Success to fetch feedback data for 192729512
# Success to fetch feedback data for 195901063
# Success to fetch feedback data for 216469489
# Success to fetch feedback data for 273534544
# Success to fetch feedback data for 210941899
# Success to fetch feedback data for 273670014
# Success to fetch feedback data for 272493335
# Success to fetch feedback data for 252217237
# Success to fetch feedback data for 204873949
# Success to fetch feedback data for 273684462
# Success to fetch feedback data for 214863390
# Success to fetch feedback data for 225917249
# Success to fetch feedback data for 189387430
# Success to fetch feedback data for 214863366
# Success to fetch feedback data for 205996665
# Success to fetch feedback data for 225917301
# Success to fetch feedback data for 224041690
# Success to fetch feedback data for 272373222
# Success to fetch feedback data for 252221655
# Success to fetch feedback data for 208679570
# Success to fetch feedback data for 251546905
# Success to fetch feedback data for 273679076
# Success to fetch feedback data for 248163672
# Success to fetch feedback data for 225195387
# Success to fetch feedback data for 214949297
# Success to fetch feedback data for 273698446
# Success to fetch feedback data for 214617998
# Success to fetch feedback data for 271380888
# Success to fetch feedback data for 273332620
# Success to fetch feedback data for 127257005
# Success to fetch feedback data for 147114276
# Success to fetch feedback data for 146952333
# Success to fetch feedback data for 222707075
# Success to fetch feedback data for 274724065
# Success to fetch feedback data for 273472177
# Success to fetch feedback data for 165875543
# Success to fetch feedback data for 259478115
# Success to fetch feedback data for 273888066
# Success to fetch feedback data for 217613027
# Success to fetch feedback data for 273949286
# Success to fetch feedback data for 181779593
# Success to fetch feedback data for 273519091
# Success to fetch feedback data for 272451911
# Success to fetch feedback data for 167383382
# Success to fetch feedback data for 186228376
# Success to fetch feedback data for 273217831
# Success to fetch feedback data for 225210585
# Success to fetch feedback data for 273520631
# Success to fetch feedback data for 273716533
# Success to fetch feedback data for 186272654
# Success to fetch feedback data for 253630371
# Success to fetch feedback data for 273786864
# Success to fetch feedback data for 158716872
# Success to fetch feedback data for 207042577
# Success to fetch feedback data for 199692559
# Success to fetch feedback data for 222604396
# Success to fetch feedback data for 252483528
# Success to fetch feedback data for 254037439
# Success to fetch feedback data for 174500984
# Success to fetch feedback data for 273502836
# Success to fetch feedback data for 204669071
# Success to fetch feedback data for 273536862
# Success to fetch feedback data for 247409237
# Success to fetch feedback data for 225210012
# Success to fetch feedback data for 273464318
# Success to fetch feedback data for 252299487
# Success to fetch feedback data for 189695021
# Success to fetch feedback data for 252172436
# Success to fetch feedback data for 274775419
# Success to fetch feedback data for 225210921
# Success to fetch feedback data for 254037204
# Success to fetch feedback data for 271472655
# Success to fetch feedback data for 205533241
# Success to fetch feedback data for 263449954
# Success to fetch feedback data for 270207472
# Success to fetch feedback data for 253630026
# Success to fetch feedback data for 198732215
# Success to fetch feedback data for 195879701
# ...
# Success to fetch feedback data for 71523926
# Success to fetch feedback data for 71073320
# Success to fetch feedback data for 71673835
# Success to fetch feedback data for 69648882
# Success to fetch feedback data for 33501278
# Success to fetch feedback data for 69457181
# Success to fetch feedback data for 80043610
# Success to fetch feedback data for 193289299
# Success to fetch feedback data for 181504471
# Success to fetch feedback data for 117812565
# Success to fetch feedback data for 190170255
# Success to fetch feedback data for 70632820
# Success to fetch feedback data for 171233558
# Success to fetch feedback data for 70634346
# Success to fetch feedback data for 194954351
# Success to fetch feedback data for 68530030
# Success to fetch feedback data for 93849733
# Success to fetch feedback data for 71093495
# Success to fetch feedback data for 70528306
# Success to fetch feedback data for 96366221
# Success to fetch feedback data for 69460049
# Success to fetch feedback data for 127377618
# Success to fetch feedback data for 174856830
# Success to fetch feedback data for 190170250
# Success to fetch feedback data for 70663195
# Success to fetch feedback data for 117812092
# Success to fetch feedback data for 71089389
# Success to fetch feedback data for 190170348
# Success to fetch feedback data for 71521150
# Success to fetch feedback data for 71524074
# Success to fetch feedback data for 71089313
# Success to fetch feedback data for 127377513
# Success to fetch feedback data for 171233713
# Success to fetch feedback data for 117812956
# Success to fetch feedback data for 82842505
# Success to fetch feedback data for 69466443
# Success to fetch feedback data for 34237440
# Success to fetch feedback data for 72302773
# Success to fetch feedback data for 171233694
# Success to fetch feedback data for 68753391
# Success to fetch feedback data for 96366267
# Success to fetch feedback data for 68609033
# Success to fetch feedback data for 68694243
# Success to fetch feedback data for 70637851
# Success to fetch feedback data for 71089370
# Success to fetch feedback data for 43186243
# Success to fetch feedback data for 72301343
# Success to fetch feedback data for 14519325
# Success to fetch feedback data for 196320215
# Success to fetch feedback data for 128288156
# Success to fetch feedback data for 69464440
# Success to fetch feedback data for 176845485
# Success to fetch feedback data for 117812555
# Success to fetch feedback data for 127377479
# Success to fetch feedback data for 70633746
# Success to fetch feedback data for 38230537
# Success to fetch feedback data for 190170609
# Success to fetch feedback data for 68692704
# Success to fetch feedback data for 117812070
# Success to fetch feedback data for 71301696
# Success to fetch feedback data for 171233528
# Success to fetch feedback data for 70631802
# Success to fetch feedback data for 71093978
# Success to fetch feedback data for 70957984
# Success to fetch feedback data for 171233629
# Success to fetch feedback data for 71665934
# Success to fetch feedback data for 70650582
# Success to fetch feedback data for 33858086
# Success to fetch feedback data for 33805851
# Success to fetch feedback data for 71094346
# Success to fetch feedback data for 56835134
# Success to fetch feedback data for 130969387
# Success to fetch feedback data for 71981333
# Success to fetch feedback data for 171233590
# Success to fetch feedback data for 71524471
# Success to fetch feedback data for 71948947
# Success to fetch feedback data for 117812465
# Success to fetch feedback data for 117811807
# Success to fetch feedback data for 171233464
# Success to fetch feedback data for 103595353
# Success to fetch feedback data for 181504686
# Success to fetch feedback data for 71093141
# Success to fetch feedback data for 194017839
# Success to fetch feedback data for 117815360
# Success to fetch feedback data for 68655751
# Success to fetch feedback data for 32923677
# Success to fetch feedback data for 72330850
# Success to fetch feedback data for 80043531
# Success to fetch feedback data for 71290926
# Success to fetch feedback data for 102780882
# Success to fetch feedback data for 171233662
# Success to fetch feedback data for 72650614
# Success to fetch feedback data for 72101532
# Success to fetch feedback data for 70638132
# Success to fetch feedback data for 33743614
# Success to fetch feedback data for 71089346
# Success to fetch feedback data for 114412341
# Success to fetch feedback data for 117813762
# Success to fetch feedback data for 193717650
# Success to fetch feedback data for 190170594
# Success to fetch feedback data for 190170163
# Success to fetch feedback data for 157412144
# Success to fetch feedback data for 117812682
# Success to fetch feedback data for 112190296
# Success to fetch feedback data for 71521888
# Success to fetch feedback data for 127377541
# Success to fetch feedback data for 72131816
# Success to fetch feedback data for 181503921
# Success to fetch feedback data for 169921409
# Success to fetch feedback data for 71958644
# Success to fetch feedback data for 171233595
# Success to fetch feedback data for 183050824
# Success to fetch feedback data for 71984404
# Success to fetch feedback data for 82842715
# Success to fetch feedback data for 121332051
# Success to fetch feedback data for 71074014
# Success to fetch feedback data for 111608564
# Success to fetch feedback data for 153980876
# Success to fetch feedback data for 68789066
# Success to fetch feedback data for 171233613
# Success to fetch feedback data for 72456232
# Success to fetch feedback data for 32505981
# Success to fetch feedback data for 54570397
# Success to fetch feedback data for 72329189
# Success to fetch feedback data for 70692112
# Success to fetch feedback data for 156001479
# Success to fetch feedback data for 95739581
# Success to fetch feedback data for 127377510
# Success to fetch feedback data for 153982039
# Success to fetch feedback data for 69445706
# Success to fetch feedback data for 93849808
# Success to fetch feedback data for 34463527
# Success to fetch feedback data for 68642710
# Success to fetch feedback data for 45098023
# Success to fetch feedback data for 136761269
# Success to fetch feedback data for 249151482
# Success to fetch feedback data for 249153396
# Success to fetch feedback data for 252582922
# Success to fetch feedback data for 272186549
# Success to fetch feedback data for 114150419
# Success to fetch feedback data for 171233720
# Success to fetch feedback data for 117812760
# Success to fetch feedback data for 244178235
# Success to fetch feedback data for 174414477
# Success to fetch feedback data for 212582543
# Success to fetch feedback data for 181504228
# Success to fetch feedback data for 72094361
# Success to fetch feedback data for 151660988
# Success to fetch feedback data for 215889906
# Success to fetch feedback data for 14506180
# Success to fetch feedback data for 242637177
# Success to fetch feedback data for 249889835
# Success to fetch feedback data for 71094029
# Success to fetch feedback data for 70638864
# Success to fetch feedback data for 194788410
# Success to fetch feedback data for 42674425
# Success to fetch feedback data for 71950272
# Success to fetch feedback data for 71208414
# Success to fetch feedback data for 240336228
# Success to fetch feedback data for 171233552
# Success to fetch feedback data for 171233470
# Success to fetch feedback data for 273688336
# Success to fetch feedback data for 71204700
# Success to fetch feedback data for 117812225
# Success to fetch feedback data for 191658853
# Success to fetch feedback data for 274551494
# Success to fetch feedback data for 117813502
# Success to fetch feedback data for 272856041
# Success to fetch feedback data for 125936161
# Success to fetch feedback data for 169692191
# Success to fetch feedback data for 169925206
# Success to fetch feedback data for 171233723
# Success to fetch feedback data for 214153828
# Success to fetch feedback data for 273054283
# Success to fetch feedback data for 145209032
# Success to fetch feedback data for 117811945
# Success to fetch feedback data for 151743803
# Success to fetch feedback data for 142370055
# Success to fetch feedback data for 273421271
# Success to fetch feedback data for 253432060
# Success to fetch feedback data for 102105735
# Success to fetch feedback data for 272365426
# Success to fetch feedback data for 252645175
# Success to fetch feedback data for 142370072
# Success to fetch feedback data for 272364256
# Success to fetch feedback data for 272366020
# Success to fetch feedback data for 70127573
# Success to fetch feedback data for 136836619
# Success to fetch feedback data for 66565951
# Success to fetch feedback data for 145209065
# Success to fetch feedback data for 117812806
# Success to fetch feedback data for 273348464
# Success to fetch feedback data for 273217377
# Success to fetch feedback data for 274410105
# Success to fetch feedback data for 171233784
# Success to fetch feedback data for 272847304
# Success to fetch feedback data for 249973345
# Success to fetch feedback data for 194406424
# Success to fetch feedback data for 272366077
# Success to fetch feedback data for 71339876
# Success to fetch feedback data for 113490236
# Success to fetch feedback data for 272267448
# Success to fetch feedback data for 191658696
# Success to fetch feedback data for 70765692
# Success to fetch feedback data for 32409589
# Success to fetch feedback data for 117812960
# Success to fetch feedback data for 249153285
# Success to fetch feedback data for 71666186
# Success to fetch feedback data for 117812395
# Success to fetch feedback data for 171233765
# Success to fetch feedback data for 117811797
# Success to fetch feedback data for 128279285
# Success to fetch feedback data for 273411018
# Success to fetch feedback data for 252664370
# Success to fetch feedback data for 121372999
# Success to fetch feedback data for 249290162
# Success to fetch feedback data for 270127465
# Success to fetch feedback data for 80043652
# Success to fetch feedback data for 160177488
# Success to fetch feedback data for 71524999
# Success to fetch feedback data for 126079660
# Success to fetch feedback data for 230038982
# Success to fetch feedback data for 71934955
# Success to fetch feedback data for 248545124
# Success to fetch feedback data for 117811772
# Success to fetch feedback data for 108844039
# Success to fetch feedback data for 71666014
# Success to fetch feedback data for 99037283
# Success to fetch feedback data for 274392356
# Success to fetch feedback data for 117812230
# Success to fetch feedback data for 71544507
# Success to fetch feedback data for 197366029
# Success to fetch feedback data for 179927580
# Success to fetch feedback data for 117813708
# Success to fetch feedback data for 82842421
# Success to fetch feedback data for 272468672
# Success to fetch feedback data for 34863103
# Success to fetch feedback data for 113260451
# Success to fetch feedback data for 171233561
# Success to fetch feedback data for 71672571
# Success to fetch feedback data for 113252316
# Success to fetch feedback data for 274923652
# Success to fetch feedback data for 200949033
# Success to fetch feedback data for 237408295
# Success to fetch feedback data for 196150839
# Success to fetch feedback data for 42699820
# Success to fetch feedback data for 196857468
# Success to fetch feedback data for 251783395
# Success to fetch feedback data for 70691818
# Success to fetch feedback data for 71880555
# Success to fetch feedback data for 181504755
# Success to fetch feedback data for 70702551
# Success to fetch feedback data for 251394901
# Success to fetch feedback data for 273443414
# Success to fetch feedback data for 82842110
# Success to fetch feedback data for 272624474
# Success to fetch feedback data for 274056769
# Success to fetch feedback data for 117813722
# Success to fetch feedback data for 71524619
# Success to fetch feedback data for 274038451
# Success to fetch feedback data for 181504766
# Success to fetch feedback data for 272052558
# Success to fetch feedback data for 72133804
# Success to fetch feedback data for 213846673
# Success to fetch feedback data for 261965623
# Success to fetch feedback data for 117811958
# Success to fetch feedback data for 253280917
# Success to fetch feedback data for 68696577
# Success to fetch feedback data for 251265111
# Success to fetch feedback data for 118263141
# Success to fetch feedback data for 72304621
# Success to fetch feedback data for 117811897
# Success to fetch feedback data for 171233609
# Success to fetch feedback data for 249591032
# Success to fetch feedback data for 96366222
# Success to fetch feedback data for 194405460
# Success to fetch feedback data for 241941658
# Success to fetch feedback data for 272829420
# Success to fetch feedback data for 244303549
# Success to fetch feedback data for 80043525
# Success to fetch feedback data for 251265764
# Success to fetch feedback data for 271438043
# Success to fetch feedback data for 70638690
# Success to fetch feedback data for 273381490
# Success to fetch feedback data for 72630418
# Success to fetch feedback data for 212553283
# Success to fetch feedback data for 70663525
# Success to fetch feedback data for 171233691
# Success to fetch feedback data for 272364838
# Success to fetch feedback data for 207205818
# Success to fetch feedback data for 253279207
# Success to fetch feedback data for 117812573
# Success to fetch feedback data for 253322748
# Success to fetch feedback data for 68767328
# Success to fetch feedback data for 193608708
# Success to fetch feedback data for 195849926
# Success to fetch feedback data for 230002108
# Success to fetch feedback data for 82842178
# Success to fetch feedback data for 171233537
# Success to fetch feedback data for 197538826
# Success to fetch feedback data for 112936982
# Success to fetch feedback data for 117259971
# Success to fetch feedback data for 200947544
# Success to fetch feedback data for 84107977
# Success to fetch feedback data for 49006682
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 product = product_ids_df.apply(get_product_data, axis=1, result_type='expand')
#       3 # Convert the result to a DataFrame
#       4 product_df = pd.DataFrame(product)
#
# File c:\Users\kietd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10347, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10333 from pandas.core.apply import frame_apply
#   10335 op = frame_apply(
#   10336     self,
#   10337     func=func,
#    (...)
#   10345     kwargs=kwargs,
#   10346 )
# > 10347 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\kietd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\kietd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\kietd\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[12], line 12, in get_product_data(row)
#      10 try:
#      11     response = requests.get(URL, headers=HEADERS, params=PARAMS)
# ---> 12     time.sleep(random.uniform(3.2, 6.2))
#      13     print(f"Success to fetch feedback data for {product_id}")
#      14     break
#
# KeyboardInterrupt:

# %%
product_df.to_csv("product_data.csv", index=False, encoding='utf-8-sig')
